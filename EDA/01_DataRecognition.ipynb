# %%
# Importando las librerias básicas
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import classification_report,plot_confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
# Cargamos datos y creamos una copia
df=pd.read_csv("creditcard.csv")

# %% [markdown]
# ---
#
# **Basic Information**
# ---
#
# ---

# %%
# Mostrar los primeros 5 datos
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.duplicated().values.any()
# Out:
# False

# %% [markdown]
# ---
#
# **Distributions of the Data**
# ---
#
# ---

# %%
df.iloc[:,:-1].hist(bins=40, figsize=(20,20))
plt.show()

# %%
df["Class"].hist()
plt.plot()
# Out:
# []

# %% [markdown]
# ---
# **Correlation Matrix**
# ---
#
# ---

# %%
plt.figure(figsize=(18,12))
ax = plt.axes()
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), linewidths=.5, fmt= '.1f',ax=ax, mask=matrix,cmap="YlGnBu")
plt.plot()
# Out:
# []

# %% [markdown]
# ---
# **Box Plots**
# ---
#
# ---

# %%
fig, axes = plt.subplots(10, 3, figsize=(20, 60))
axes = axes.reshape(30,)

for i,column in enumerate(df.columns[:-1]):
    axes[i].set_yscale('symlog')
    sns.boxplot(ax = axes[i],x="Class", y=column,data=df, palette="Set3")

# %% [markdown]
# ---
# **Observations**
# ---
#
# ---
#
#
# 1.   The shape of the dataset is (284807, 31)
# 2.   The Dataset haven´t null or duplicated elements.
# 3.   We dont have cathegorical data.
# 4.   Each variable in the dataset is scaled.
# 5.   The dataset is highly imbalanced (less than one percent of the data is from the class 1).
# 6.   In the correlation matrix we can see some interesting variables that could be related with the interest class.
# 7.   The box plots show some atypical data in the class 0, must be examined.
